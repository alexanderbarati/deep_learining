# %% [markdown]
# # Multi-Layer Perceptron, MNIST
#
# In this notebook, I will train an MLP to classify images from the [MNIST database](http://yann.lecun.com/exdb/mnist/) hand-written digit database.

# %% [markdown]
# ##### importing necessary libraries

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##### Load and Visualize the [Data](http://pytorch.org/docs/stable/torchvision/datasets.html)

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# %%
# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# %% [markdown]
# ##### choose the training and test datasets

# %%
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)

# %% [markdown]
# ##### Obtain training idices that will be used for validation

# %%
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# %% [markdown]
# ##### define samplers for obtaining training and validation batches

# %%
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %% [markdown]
# ##### prepare data loaders

# %%
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# %% [markdown]
# ### Visualize a Batch of Training Data
# let's take a look at the data

# %% [markdown]
# ##### obtain one batch of training images

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# %% [markdown]
# ##### plot the images in the batch, along with the corresponding labels

# %%
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    # print out the correct label for each image
    # .item() gets the value contained in a Tensor
    ax.set_title(str(labels[idx].item()))

# %% [markdown]
# ### View an Image in More Detail

# %%
img = np.squeeze(images[10]) # removing number of batch

fig = plt.figure(figsize = (12,12)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y],2) if img[x][y] !=0 else 0
        ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Define the Network [Architecture](http://pytorch.org/docs/stable/nn.html)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ##### Define the NN architecture

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # number of hidden nodes in each layer (512)
        hidden_1 = 512
        hidden_2 = 512
        # linear layer (784 -> hidden_1)
        self.fc1 = nn.Linear(28 * 28, hidden_1)
        # linear layer (n_hidden -> hidden_2)
        self.fc2 = nn.Linear(hidden_1, hidden_2)
        # linear layer (n_hidden -> 10)
        self.fc3 = nn.Linear(hidden_2, 10)
        # dropout layer (p=0.2)
        # dropout prevents overfitting of data
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        # flatten image input
        x = x.view(-1, 28 * 28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer
        x = self.dropout(x)
        # add output layer
        x = self.fc3(x)
        return x

# initialize the NN
model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %% [markdown]
# ###  Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# It's recommended that you use cross-entropy loss for classification.

# %%
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr= 0.01)

# %% [markdown]
# ---
# ## Train the Network
#
# The steps for training/learning from a batch of data are described in the comments below:
# 1. Clear the gradients of all optimized variables
# 2. Forward pass: compute predicted outputs by passing inputs to the model
# 3. Calculate the loss
# 4. Backward pass: compute gradient of the loss with respect to model parameters
# 5. Perform a single optimization step (parameter update)
# 6. Update average training loss
#
# The following loop trains for 50 epochs; take a look at how the values for the training loss decrease over time. I want it to decrease while also avoiding overfitting the training data.

# %%
# number of epochs to train the model
n_epochs = 50

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train() # prep model for training
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval() # prep model for evaluation
    for data, target in valid_loader:
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()*data.size(0)
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.943320 	Validation Loss: 0.386155
# Validation loss decreased (inf --> 0.386155).  Saving model ...
# Epoch: 2 	Training Loss: 0.356815 	Validation Loss: 0.287879
# Validation loss decreased (0.386155 --> 0.287879).  Saving model ...
# Epoch: 3 	Training Loss: 0.283810 	Validation Loss: 0.241364
# Validation loss decreased (0.287879 --> 0.241364).  Saving model ...
# Epoch: 4 	Training Loss: 0.233338 	Validation Loss: 0.201479
# Validation loss decreased (0.241364 --> 0.201479).  Saving model ...
# Epoch: 5 	Training Loss: 0.198430 	Validation Loss: 0.176900
# Validation loss decreased (0.201479 --> 0.176900).  Saving model ...
# Epoch: 6 	Training Loss: 0.172953 	Validation Loss: 0.157866
# Validation loss decreased (0.176900 --> 0.157866).  Saving model ...
# Epoch: 7 	Training Loss: 0.152629 	Validation Loss: 0.142171
# Validation loss decreased (0.157866 --> 0.142171).  Saving model ...
# Epoch: 8 	Training Loss: 0.135623 	Validation Loss: 0.130541
# Validation loss decreased (0.142171 --> 0.130541).  Saving model ...
# Epoch: 9 	Training Loss: 0.122999 	Validation Loss: 0.121263
# Validation loss decreased (0.130541 --> 0.121263).  Saving model ...
# Epoch: 11 	Training Loss: 0.102256 	Validation Loss: 0.106607
# Validation loss decreased (0.114123 --> 0.106607).  Saving model ...
# Epoch: 12 	Training Loss: 0.093299 	Validation Loss: 0.100226
# Validation loss decreased (0.106607 --> 0.100226).  Saving model ...
# Epoch: 13 	Training Loss: 0.087209 	Validation Loss: 0.095906
# Validation loss decreased (0.100226 --> 0.095906).  Saving model ...
# Epoch: 14 	Training Loss: 0.081226 	Validation Loss: 0.093287
# Validation loss decreased (0.095906 --> 0.093287).  Saving model ...
# Epoch: 15 	Training Loss: 0.074457 	Validation Loss: 0.087994
# Validation loss decreased (0.093287 --> 0.087994).  Saving model ...
# Epoch: 16 	Training Loss: 0.069944 	Validation Loss: 0.085892
# Validation loss decreased (0.087994 --> 0.085892).  Saving model ...
# Epoch: 17 	Training Loss: 0.066358 	Validation Loss: 0.083821
# Validation loss decreased (0.085892 --> 0.083821).  Saving model ...
# Epoch: 18 	Training Loss: 0.062041 	Validation Loss: 0.082375
# Validation loss decreased (0.083821 --> 0.082375).  Saving model ...
# Epoch: 19 	Training Loss: 0.057278 	Validation Loss: 0.080872
# Validation loss decreased (0.082375 --> 0.080872).  Saving model ...
# Epoch: 20 	Training Loss: 0.054941 	Validation Loss: 0.075313
# Validation loss decreased (0.080872 --> 0.075313).  Saving model ...
# Epoch: 21 	Training Loss: 0.049783 	Validation Loss: 0.074508
# Validation loss decreased (0.075313 --> 0.074508).  Saving model ...
# Epoch: 22 	Training Loss: 0.048644 	Validation Loss: 0.073103
# Validation loss decreased (0.074508 --> 0.073103).  Saving model ...
# Epoch: 23 	Training Loss: 0.044997 	Validation Loss: 0.072658
# Validation loss decreased (0.073103 --> 0.072658).  Saving model ...
# Epoch: 24 	Training Loss: 0.042297 	Validation Loss: 0.070743
# Validation loss decreased (0.072658 --> 0.070743).  Saving model ...
# Epoch: 25 	Training Loss: 0.041943 	Validation Loss: 0.070875
# Epoch: 26 	Training Loss: 0.038635 	Validation Loss: 0.071347
# Epoch: 27 	Training Loss: 0.036268 	Validation Loss: 0.068372
# Validation loss decreased (0.070743 --> 0.068372).  Saving model ...
# Epoch: 28 	Training Loss: 0.034583 	Validation Loss: 0.067599
# Validation loss decreased (0.068372 --> 0.067599).  Saving model ...
# Epoch: 29 	Training Loss: 0.033022 	Validation Loss: 0.067694
# Epoch: 30 	Training Loss: 0.031131 	Validation Loss: 0.067092
# Validation loss decreased (0.067599 --> 0.067092).  Saving model ...
# Epoch: 31 	Training Loss: 0.029478 	Validation Loss: 0.066779
# Validation loss decreased (0.067092 --> 0.066779).  Saving model ...
# Epoch: 32 	Training Loss: 0.028494 	Validation Loss: 0.066500
# Validation loss decreased (0.066779 --> 0.066500).  Saving model ...
# Epoch: 33 	Training Loss: 0.026322 	Validation Loss: 0.065930
# Validation loss decreased (0.066500 --> 0.065930).  Saving model ...
# Epoch: 34 	Training Loss: 0.025193 	Validation Loss: 0.066950
# Epoch: 35 	Training Loss: 0.023317 	Validation Loss: 0.066650
# Epoch: 36 	Training Loss: 0.023505 	Validation Loss: 0.065738
# Validation loss decreased (0.065930 --> 0.065738).  Saving model ...
# Epoch: 37 	Training Loss: 0.022774 	Validation Loss: 0.065158
# Validation loss decreased (0.065738 --> 0.065158).  Saving model ...
# Epoch: 38 	Training Loss: 0.021188 	Validation Loss: 0.063872
# Validation loss decreased (0.065158 --> 0.063872).  Saving model ...
# Epoch: 39 	Training Loss: 0.020122 	Validation Loss: 0.065326
# Epoch: 40 	Training Loss: 0.019712 	Validation Loss: 0.064094
# Epoch: 41 	Training Loss: 0.018609 	Validation Loss: 0.067597
# Epoch: 42 	Training Loss: 0.017965 	Validation Loss: 0.066012
# Epoch: 43 	Training Loss: 0.017923 	Validation Loss: 0.062889
# Validation loss decreased (0.063872 --> 0.062889).  Saving model ...
# Epoch: 44 	Training Loss: 0.016045 	Validation Loss: 0.064813
# Epoch: 45 	Training Loss: 0.016501 	Validation Loss: 0.065268
# Epoch: 46 	Training Loss: 0.014922 	Validation Loss: 0.064201
# Epoch: 47 	Training Loss: 0.014871 	Validation Loss: 0.064454
# Epoch: 48 	Training Loss: 0.014424 	Validation Loss: 0.067104
# Epoch: 49 	Training Loss: 0.013768 	Validation Loss: 0.067069
# Epoch: 50 	Training Loss: 0.013495 	Validation Loss: 0.065501

# %% [markdown]
# ###  Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model.pt'))

# %% [markdown]
# ## Test the Trained Network
#
# Finally, we test our best model on previously unseen **test data** and evaluate it's performance. Testing on unseen data is a good way to check that our model generalizes well. It may also be useful to be granular in this analysis and take a look at how this model performs on each class as well as looking at its overall loss and accuracy.

# %%
# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() # prep model for evaluation

for data, target in test_loader:
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print avg test loss
test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.057747
#
# Test Accuracy of     0: 98% (970/980)
# Test Accuracy of     1: 99% (1124/1135)
# Test Accuracy of     2: 97% (1009/1032)
# Test Accuracy of     3: 98% (992/1010)
# Test Accuracy of     4: 98% (966/982)
# Test Accuracy of     5: 97% (874/892)
# Test Accuracy of     6: 98% (943/958)
# Test Accuracy of     7: 97% (1003/1028)
# Test Accuracy of     8: 97% (949/974)
# Test Accuracy of     9: 97% (988/1009)
#
# Test Accuracy (Overall): 98% (9818/10000)

# %% [markdown]
# ### Visualize Sample Test Results
#
# This cell displays test images and their labels in this format: `predicted (ground-truth)`. The text will be green for accurately classified examples and red for incorrect predictions.

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))
